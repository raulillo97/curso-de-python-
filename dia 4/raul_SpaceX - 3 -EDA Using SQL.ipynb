# %% [markdown]
# # Etapa 3: Análisis de datos utilizando SQL

# %% [markdown]
# ## Objetivos
#
# En esta práctica subiremos los datos a una base de datos SQL y realizaremos diferentes queries para obtener información sobre los datos

# %%
# !pip install sqlalchemy==1.4.16 --quiet
import pandas as pd
import numpy as np
# !pip install PyMySQL --quiet
import pymysql as pymsql
# !pip install mysql-connector --quiet
import mysql.connector
from sqlalchemy import create_engine
# !pip install sqlalchemy-utils --quiet
from sqlalchemy_utils import database_exists, create_database
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Tarea 1: Subir los datos a la base de datos:

# %% [markdown]
# Primero cargamos el archivo de datos `dataset_part_2.csv`.

# %%
df_path = "/content/dataset_part_2 (1).csv"
df = pd.read_csv(df_path)

# %%
#Rellena la siguiente variable con tu nombre y apellido (Todo junto y sin espacios).
nombreBD = 'raulhernandezcapilla'
linkConexion = 'mysql+mysqlconnector://alumno:385bd4cf713a8a36@35.180.211.139/' + nombreBD
#Establecemos la conexión
engine = create_engine(linkConexion)

# %%
if not database_exists(engine.url):
    create_database(engine.url)

# %%
# Añadir el dataframe a sql SPACEXTBL usando la función to_sql().
df.to_sql("SPACEXTBL",engine)# Para subir los datos a la base de datos
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-c854e04731dc> in <cell line: 2>()
#       1 # Añadir el dataframe a sql SPACEXTBL usando la función to_sql().
# ----> 2 df.to_sql("SPACEXTBL",engine)# Para subir los datos a la base de datos
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2985         from pandas.io import sql
#    2986
# -> 2987         return sql.to_sql(
#    2988             self,
#    2989             name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693         )
#     694
# --> 695     return pandas_sql.to_sql(
#     696         frame,
#     697         name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1726         sql_engine = get_engine(engine)
#    1727
# -> 1728         table = self.prep_table(
#    1729             frame=frame,
#    1730             name=name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1629             dtype=dtype,
#    1630         )
# -> 1631         table.create()
#    1632         return table
#    1633
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in create(self)
#     827         if self.exists():
#     828             if self.if_exists == "fail":
# --> 829                 raise ValueError(f"Table '{self.name}' already exists.")
#     830             elif self.if_exists == "replace":
#     831                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'SPACEXTBL' already exists.

# %%
query = "select * from SPACEXTBL;"
df  = pd.read_sql(query,  engine )
df
# Out:
#     index  FlightNumber        Date BoosterVersion   PayloadMass  \
# 0       0             1  2010-06-04       Falcon 9   6123.547647
# 1       1             2  2012-05-22       Falcon 9    525.000000
# 2       2             3  2013-03-01       Falcon 9    677.000000
# 3       3             4  2013-09-29       Falcon 9    500.000000
# 4       4             5  2013-12-03       Falcon 9   3170.000000
# ..    ...           ...         ...            ...           ...
# 85     85            86  2020-09-03       Falcon 9  15600.000000
# 86     86            87  2020-10-06       Falcon 9  15600.000000
# 87     87            88  2020-10-18       Falcon 9  15600.000000
# 88     88            89  2020-10-24       Falcon 9  15600.000000
# 89     89            90  2020-11-05       Falcon 9   3681.000000
#
#                       Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0   Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1          COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                       CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                    CASSIOPE    PO   VAFB SLC 4E    False Ocean        1
# 4                       SES-8   GTO  CCSFS SLC 40      None None        1
# ..                        ...   ...           ...            ...      ...
# 85                Starlink-11  VLEO    KSC LC 39A      True ASDS        2
# 86                Starlink-12  VLEO    KSC LC 39A      True ASDS        3
# 87                Starlink-13  VLEO    KSC LC 39A      True ASDS        6
# 88                Starlink-14  VLEO  CCSFS SLC 40      True ASDS        3
# 89   GPS III SV04 (Sacagawea)   MEO  CCSFS SLC 40      True ASDS        1
#
#     GridFins  Reused  Legs                LandingPad  Block  \
# 0          0       0     0                      None    1.0
# 1          0       0     0                      None    1.0
# 2          0       0     0                      None    1.0
# 3          0       0     0                      None    1.0
# 4          0       0     0                      None    1.0
# ..       ...     ...   ...                       ...    ...
# 85         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 86         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 87         1       1     1  5e9e3032383ecb6bb234e7ca    5.0
# 88         1       1     1  5e9e3033383ecbb9e534e7cc    5.0
# 89         1       0     1  5e9e3032383ecb6bb234e7ca    5.0
#
#                     Customers  Mission_Outcome  ReusedCount Serial  \
# 0                      SpaceX                1            0  B0003
# 1                  NASA(COTS)                1            0  B0005
# 2                  NASA (CRS)                1            0  B0007
# 3                         MDA                1            0  B1003
# 4                         SES                1            0  B1004
# ..                        ...              ...          ...    ...
# 85                     SpaceX                1           12  B1060
# 86                     SpaceX                1           13  B1058
# 87                     SpaceX                1           12  B1051
# 88                     SpaceX                1           12  B1060
# 89  United States Space Force                1            8  B1062
#
#      Longitude   Latitude  Class
# 0   -80.577366  28.561857      0
# 1   -80.577366  28.561857      0
# 2   -80.577366  28.561857      0
# 3  -120.610829  34.632093      0
# 4   -80.577366  28.561857      0
# ..         ...        ...    ...
# 85  -80.603956  28.608058      1
# 86  -80.603956  28.608058      1
# 87  -80.603956  28.608058      1
# 88  -80.577366  28.561857      1
# 89  -80.577366  28.561857      1
#
# [90 rows x 22 columns]

# %% [markdown]
# ## Tarea 2: Queries con SQL

# %% [markdown]
# ### Ejercicio 1
#
# ##### Muestra las diferentes plataformas de lanzamiento:

# %%
#Rellena la variable query con tu consulta
query = """  SELECT DISTINCT(LaunchSite)
             FROM SPACEXTBL  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#      LaunchSite
# 0  CCSFS SLC 40
# 1   VAFB SLC 4E
# 2    KSC LC 39A

# %% [markdown]
# ### Ejercicio 2
#
# ##### Muestra 5 lanzamientos cuya plataforma empiece por 'CCS'

# %%
#Rellena la variable query con tu consulta, es lo mismo que filtrar por las fila que tengan ccs
query = """  SELECT *
FROM SPACEXTBL
WHERE LaunchSite LIKE 'CCS%'
LIMIT 5;  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    index  FlightNumber        Date BoosterVersion  PayloadMass  \
# 0      0             1  2010-06-04       Falcon 9  6123.547647
# 1      1             2  2012-05-22       Falcon 9   525.000000
# 2      2             3  2013-03-01       Falcon 9   677.000000
# 3      4             5  2013-12-03       Falcon 9  3170.000000
# 4      5             6  2014-01-06       Falcon 9  3325.000000
#
#                      Payload Orbit    LaunchSite LandingOutcome  Flights  \
# 0  Dragon Qualification Unit   LEO  CCSFS SLC 40      None None        1
# 1         COTS Demo Flight 2   LEO  CCSFS SLC 40      None None        1
# 2                      CRS-2   ISS  CCSFS SLC 40      None None        1
# 3                      SES-8   GTO  CCSFS SLC 40      None None        1
# 4                  Thaicom 6   GTO  CCSFS SLC 40      None None        1
#
#    GridFins  Reused  Legs LandingPad  Block   Customers  Mission_Outcome  \
# 0         0       0     0       None    1.0      SpaceX                1
# 1         0       0     0       None    1.0  NASA(COTS)                1
# 2         0       0     0       None    1.0  NASA (CRS)                1
# 3         0       0     0       None    1.0         SES                1
# 4         0       0     0       None    1.0     Thaicom                1
#
#    ReusedCount Serial  Longitude   Latitude  Class
# 0            0  B0003 -80.577366  28.561857      0
# 1            0  B0005 -80.577366  28.561857      0
# 2            0  B0007 -80.577366  28.561857      0
# 3            0  B1004 -80.577366  28.561857      0
# 4            0  B1005 -80.577366  28.561857      0

# %% [markdown]
# ### Ejercicio 3
#
# ##### Mustra el la masa total transportada por los lanzamientos realizados donde el cliente es NASA (CRS)

# %%
query = """  SELECT Customers, SUM(PayloadMass) AS masa_total_transportada
FROM SPACEXTBL
WHERE Customers = 'NASA (CRS)';   """
df  = pd.read_sql(query, con = engine )
df
# Out:
#     Customers  masa_total_transportada
# 0  NASA (CRS)                  47094.7

# %% [markdown]
# ### Ejercicio 4
#
# ##### Muestra la masa media tranportada por lanzamientos con serie que comienza por B1

# %%
query = """  SELECT Serial, AVG(PayloadMass) AS masa_media_transportada
FROM SPACEXTBL
WHERE Serial LIKE 'B1%';  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#   Serial  masa_media_transportada
# 0  B1003              6250.502765

# %% [markdown]
# ### Ejercicio 5
#
# ##### Muestra la fecha donde se realizo el primer aterrizaje exitoso sobre terreno (TRUE RTLS)
#
# *Pista:Utiliza la función min*

# %%
query = """  SELECT LandingOutcome, MIN(Date) AS primera_fecha_aterrizaje_exitoso
FROM SPACEXTBL
WHERE LandingOutcome = 'true RTLS';   """
df  = pd.read_sql(query, con = engine )
df
# Out:
#   LandingOutcome primera_fecha_aterrizaje_exitoso
# 0      True RTLS                       2015-12-22

# %% [markdown]
# ### Ejercicio 6
#
# ##### Muestra las series de los cohetes que aterrizaron sobre portaviones (TRUE ASDS) con una masa entre 4000 y 6000

# %%
query = """  SELECT Serial, PayloadMass
FROM SPACEXTBL
WHERE PayloadMass between 4000 AND 6000 AND LandingOutcome = 'true ASDS ';   """
df  = pd.read_sql(query, con = engine )
df
# Out:
#   Serial  PayloadMass
# 0  B1022       4696.0
# 1  B1026       4600.0
# 2  B1021       5300.0
# 3  B1031       5200.0
# 4  B1046       5800.0
# 5  B1046       4000.0
# 6  B1059       5000.0

# %% [markdown]
# ### Ejercicio 7
#
# ##### Muestra el numero de lanzamientos que completaron su mision correctamente y aquellos que fallaron

# %%
query = """   SELECT LandingOutcome	, COUNT(Flights) as cantidad_de_lanzamientos
FROM SPACEXTBL
WHERE LandingOutcome	like 'True%' or LandingOutcome	like  'False%'
GROUP BY LandingOutcome;   """
df  = pd.read_sql(query, con = engine )
df
# Out:
#   LandingOutcome  cantidad_de_lanzamientos
# 0     False ASDS                         6
# 1    False Ocean                         2
# 2     False RTLS                         1
# 3      True ASDS                        41
# 4     True Ocean                         5
# 5      True RTLS                        14

# %% [markdown]
# ### Ejercicio 8
#
# ##### Muestra las series de los cohetes que transportaron la masa máxima

# %%
query = """  SELECT Serial, PayloadMass
FROM SPACEXTBL
WHERE PayloadMass = (SELECT MAX(PayloadMass) FROM SPACEXTBL);  """
df  = pd.read_sql(query, con = engine )
df
# Out:
#    Serial  PayloadMass
# 0   B1048      15600.0
# 1   B1049      15600.0
# 2   B1051      15600.0
# 3   B1056      15600.0
# 4   B1048      15600.0
# 5   B1051      15600.0
# 6   B1049      15600.0
# 7   B1059      15600.0
# 8   B1049      15600.0
# 9   B1060      15600.0
# 10  B1058      15600.0
# 11  B1051      15600.0
# 12  B1060      15600.0

# %% [markdown]
# ### Ejercicio 9
#
# ##### Muestra los el resultados del aterrizaje, la serie del cohete y las plataforma de lanzamiento de aquellos lanzamientos fallidos o no intentados en el año 2015

# %%
query = """  SELECT Serial, LandingOutcome,LandingPad, Date
FROM SPACEXTBL
WHERE (LandingOutcome like 'False%'
or LandingOutcome LIKE 'None%')
AND YEAR ( Date ) = 2015 """
df  = pd.read_sql(query, con = engine )
df
# Out:
#   Serial LandingOutcome                LandingPad        Date
# 0  B1012     False ASDS  5e9e3032383ecb761634e7cb  2015-01-10
# 1  B1015     False ASDS  5e9e3032383ecb761634e7cb  2015-04-14
# 2  B1016      None None                      None  2015-04-27
# 3  B1018      None ASDS  5e9e3032383ecb6bb234e7ca  2015-06-28

# %% [markdown]
# ### Ejercicio 10
#
# ##### Muestra los resultados y la frecuencia de estos resultados entre 2010-06-04 y 2017-03-20 ordenados en orden descendiente según la frecuencia

# %%
query = """  SELECT LandingOutcome, COUNT(LandingOutcome) as frecuencia
FROM SPACEXTBL
WHERE DATE between '2010-06-04' AND '2017-03-20'
GROUP BY LandingOutcome
ORDER BY DESC """
df  = pd.read_sql(query, con = engine )
df
# Out:
#   LandingOutcome  frecuencia
# 0     False ASDS           4
# 1    False Ocean           2
# 2      None ASDS           2
# 3      None None           9
# 4      True ASDS           5
# 5     True Ocean           3
# 6      True RTLS           3
